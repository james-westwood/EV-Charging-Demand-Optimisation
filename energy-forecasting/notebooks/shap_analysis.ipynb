# %% [markdown]
# # SHAP Analysis

# %% [markdown]
# Plan for this analysis:
#
# 1. Load the P50 model from MLflow
# 2. Load the feature data
# 3. Run SHAP — shap.TreeExplainer on the LightGBM model
# 4. Beeswarm plot — shows feature importance and direction for all predictions (the classic SHAP summary plot)
#
# 5. Bar plot — mean absolute SHAP values, clean ranking of top features
#
# 6. A few sentences of commentary between cells interpreting what you see

# %%
# load the p50 model from MLflow

import mlflow.lightgbm
